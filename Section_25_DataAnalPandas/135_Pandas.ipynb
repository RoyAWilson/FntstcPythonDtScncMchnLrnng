# %% [markdown]
# # Part 2 Section 25 Data Analytics and Wrangling with Pandas:
#
# ##### Lecture 135: Introduction to Pandas
# ##### Lecture 136: Read CSV and Dataframees Basics
# ##### Lecture 137: Save CSV Files
# ##### Lecture 138: Tab Delimited Text Files
# ##### Lecture 139: Exploratory Data Analysis
# ##### Lecture 140: Selecting Columns From a Dataframd
# ##### Lecture 141: Filtering Rows
# ##### Lecture 142: Sorting Dataframes
# ##### Lecture 143: Counting Rows and Non-Missing Values
# ##### Lecture 144: Counting Unique Values
# ##### Lecture 145: Get all Unique Values
# ##### Lecture 146: Aggregation and Summary Statistics
# ##### Lecture 147: Vectorised Computations
# ##### Lecture 148: Conditional Computations/Assignment by Rows

# %%
import pandas as pd
import numpy as np

# %%
# 0.A Read a CSV File:
data = pd.read_csv(r'../Resources/california_restaurants.csv')

# %%
data.head(5)
# Out:
#                                             Yelp URL                   Name  \
# 0  https://www.yelp.com/biz/in-s%C4%ABt-coffee-bu...          In-sīt Coffee
# 1  https://www.yelp.com/biz/tierra-mia-coffee-wes...      Tierra Mia Coffee
# 2       https://www.yelp.com/biz/julies-cafe-chino-3           Julie's Cafe
# 3  https://www.yelp.com/biz/bonanza-bakery-and-ca...  Bonanza Bakery & Cafe
# 4           https://www.yelp.com/biz/dripp-fullerton                  Dripp
#
#                           Street Address  Zip Code               City State  \
# 0               6930 Beach Blvd Ste L301   90621.0         Buena Park    CA
# 1                      2301 S Azusa Ave    91792.0        West Covina    CA
# 2                     3746 Riverside Dr    91710.0              Chino    CA
# 3  20657 Golden Springs Dr Ste - 104,105   91789.0        Diamond Bar    CA
# 4                                              NaN  500 N Harbor Blvd   NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Yelp URL           1273 non-null   object
#  1   Name               1273 non-null   object
#  2   Street Address     1273 non-null   object
#  3   Zip Code           1259 non-null   float64
#  4   City               1263 non-null   object
#  5   State              1259 non-null   object
#  6   Price Range        1067 non-null   object
#  7   Phone              1196 non-null   object
#  8   Rating             1270 non-null   float64
#  9   Number of Reviews  1270 non-null   float64
#  10  Website            974 non-null    object
#  11  Menu Link          591 non-null    object
#  12  Image 1            1268 non-null   object
#  13  Image 2            1262 non-null   object
#  14  Image 3            1255 non-null   object
#  15  Category 1         1273 non-null   object
# ...

# %%
 # 0.B Write CSV Files:
# Goes through writing the file just opened to the hard drive using .to_csv
# And how to save without the index - .to_csv('Path/name.csv', index=False)
# Also goes through saving as a tab delimited file with sep='\t'
# Then goes through opening a tab delimited file with sep='\t'

# %%
# 1 Exploratory Analysis:

data.describe()
# Out:
#            Zip Code       Rating  Number of Reviews
# count   1259.000000  1270.000000        1270.000000
# mean   92180.524226     4.260630         593.224409
# std      773.349154     0.488022         895.677114
# min    90601.000000     1.500000           1.000000
# 25%    91748.000000     4.000000          87.000000
# 50%    92802.000000     4.500000         262.000000
# 75%    92831.000000     4.500000         704.500000
# max    92887.000000     5.000000        6836.000000

# %%
# 2 Selecting Columns from a Dataframe:
# Take out Restaurant Name, City and Rating:

df_1 = data[ ['Name', 'City', 'Rating'] ]
df_1
# Out:
#                            Name               City  Rating
# 0                 In-sīt Coffee         Buena Park     4.0
# 1             Tierra Mia Coffee        West Covina     4.0
# 2                  Julie's Cafe              Chino     4.5
# 3         Bonanza Bakery & Cafe        Diamond Bar     4.0
# 4                         Dripp  500 N Harbor Blvd     4.0
# ...                         ...                ...     ...
# 1268                 Ap Gu Jung        Diamond Bar     4.5
# 1269                 Yard House               Brea     3.5
# 1270                    Club 33            Anaheim     4.5
# 1271      Midoh Rowland Heights    Rowland Heights     4.0
# 1272  Dollar Hits - West Covina        West Covina     4.5
#
# [1273 rows x 3 columns]

# %%
# Take out rating column:

data['Rating']
# Out:
# 0       4.0
# 1       4.0
# 2       4.5
# 3       4.0
# 4       4.0
#        ...
# 1268    4.5
# 1269    3.5
# 1270    4.5
# 1271    4.0
# 1272    4.5
# Name: Rating, Length: 1273, dtype: float64

# %%
# 3 Filtering Rows by conditions:
# Method 1 using dot loc

# Step 1 create a logical mask:

mask = data['City'] == 'Chino'
chino_restaurants = data[mask]
chino_restaurants
# Out:
#                                                Yelp URL  \
# 2          https://www.yelp.com/biz/julies-cafe-chino-3
# 31        https://www.yelp.com/biz/canabru-coffee-chino
# 89          https://www.yelp.com/biz/victory-cafe-chino
# 96    https://www.yelp.com/biz/the-flinderstreet-caf...
# 191      https://www.yelp.com/biz/painted-dough-chino-2
# 199   https://www.yelp.com/biz/the-perfect-spot-chin...
# 259       https://www.yelp.com/biz/canabru-coffee-chino
# 368         https://www.yelp.com/biz/victory-cafe-chino
# 503   https://www.yelp.com/biz/the-flinderstreet-caf...
# 513   https://www.yelp.com/biz/the-perfect-spot-chin...
# 594   https://www.yelp.com/biz/the-19th-hole-lounge-...
# 610   https://www.yelp.com/biz/the-vintners-tavern-c...
# 721      https://www.yelp.com/biz/nguyens-kitchen-chino
# 737   https://www.yelp.com/biz/ray-and-sandys-hideaw...
# 813   https://www.yelp.com/biz/the-19th-hole-lounge-...
# 995      https://www.yelp.com/biz/yoshiharu-ramen-chino
# ...

# %%
# Another, apparently more accurate way of doing things:

data.loc[mask, :]
# Out:
#                                                Yelp URL  \
# 2          https://www.yelp.com/biz/julies-cafe-chino-3
# 31        https://www.yelp.com/biz/canabru-coffee-chino
# 89          https://www.yelp.com/biz/victory-cafe-chino
# 96    https://www.yelp.com/biz/the-flinderstreet-caf...
# 191      https://www.yelp.com/biz/painted-dough-chino-2
# 199   https://www.yelp.com/biz/the-perfect-spot-chin...
# 259       https://www.yelp.com/biz/canabru-coffee-chino
# 368         https://www.yelp.com/biz/victory-cafe-chino
# 503   https://www.yelp.com/biz/the-flinderstreet-caf...
# 513   https://www.yelp.com/biz/the-perfect-spot-chin...
# 594   https://www.yelp.com/biz/the-19th-hole-lounge-...
# 610   https://www.yelp.com/biz/the-vintners-tavern-c...
# 721      https://www.yelp.com/biz/nguyens-kitchen-chino
# 737   https://www.yelp.com/biz/ray-and-sandys-hideaw...
# 813   https://www.yelp.com/biz/the-19th-hole-lounge-...
# 995      https://www.yelp.com/biz/yoshiharu-ramen-chino
# ...

# %%
data.loc[mask, ['Name', 'City', 'Rating']]
# Out:
#                                  Name   City  Rating
# 2                        Julie's Cafe  Chino     4.5
# 31                     Canabru Coffee  Chino     4.0
# 89                       Victory Cafe  Chino     5.0
# 96             The Flinderstreet Cafe  Chino     4.5
# 191                     Painted Dough  Chino     4.5
# 199            The Perfect Spot Chino  Chino     4.5
# 259                    Canabru Coffee  Chino     4.0
# 368                      Victory Cafe  Chino     5.0
# 503            The Flinderstreet Cafe  Chino     4.5
# 513            The Perfect Spot Chino  Chino     4.5
# 594              The 19th Hole Lounge  Chino     5.0
# 610              The Vintner's Tavern  Chino     4.5
# 721                  Nguyen's Kitchen  Chino     4.0
# 737            Ray & Sandy's Hideaway  Chino     4.0
# 813              The 19th Hole Lounge  Chino     5.0
# 995                   Yoshiharu Ramen  Chino     4.5
# 1002                      Tacos Y Más  Chino     4.5
# ...

# %%
# 4 Sorting Dataframes:

data.sort_values(by='Rating', ascending=False)
# Out:
#                                               Yelp URL  \
# 636  https://www.yelp.com/biz/the-post-pub-yorba-linda
# 184  https://www.yelp.com/biz/grace-book-cafe-fulle...
# 163  https://www.yelp.com/biz/ethnos-coffee-whittier-2
# 375  https://www.yelp.com/biz/paris-baguette-boulan...
# 167   https://www.yelp.com/biz/chiptune-coffee-anaheim
# ..                                                 ...
# 829  https://www.yelp.com/biz/the-leaky-tiki-bar-la...
# 562  https://www.yelp.com/biz/mexico-de-noche-anahe...
# 102        https://www.yelp.com/biz/and-more-anaheim-3
# 697  https://www.yelp.com/biz/grimpy-grumps-grub-on...
# 876          https://www.yelp.com/biz/bbq-chicken-brea
#
#                            Name               Street Address  Zip Code  \
# 636                The Post Pub     5091 Richfield Rd Unit A   92886.0
# 184             Grace Book Cafe          1645 W Valencia Dr    92833.0
# 163               Ethnos Coffee                                    NaN
# ...

# %%
data = data.loc[data['City'].notna()]
data
# Out:
#                                                Yelp URL  \
# 0     https://www.yelp.com/biz/in-s%C4%ABt-coffee-bu...
# 1     https://www.yelp.com/biz/tierra-mia-coffee-wes...
# 2          https://www.yelp.com/biz/julies-cafe-chino-3
# 3     https://www.yelp.com/biz/bonanza-bakery-and-ca...
# 4              https://www.yelp.com/biz/dripp-fullerton
# ...                                                 ...
# 1268    https://www.yelp.com/biz/ap-gu-jung-diamond-bar
# 1269         https://www.yelp.com/biz/yard-house-brea-4
# 1270         https://www.yelp.com/biz/club-33-anaheim-3
# 1271  https://www.yelp.com/biz/midoh-rowland-heights...
# 1272  https://www.yelp.com/biz/dollar-hits-west-covi...
#
#                            Name                         Street Address  \
# 0                 In-sīt Coffee               6930 Beach Blvd Ste L301
# 1             Tierra Mia Coffee                      2301 S Azusa Ave
# 2                  Julie's Cafe                     3746 Riverside Dr
# ...

# %%
data.sort_values('City', inplace=True)
data
# Out:
#                                                Yelp URL  \
# 4              https://www.yelp.com/biz/dripp-fullerton
# 257            https://www.yelp.com/biz/dripp-fullerton
# 255   https://www.yelp.com/biz/awaken-coffee-yorba-l...
# 42    https://www.yelp.com/biz/awaken-coffee-yorba-l...
# 895   https://www.yelp.com/biz/craft-by-smoke-and-fi...
# ...                                                 ...
# 283   https://www.yelp.com/biz/perking-house-coffee-...
# 241   https://www.yelp.com/biz/peet-s-coffee-yorba-l...
# 238   https://www.yelp.com/biz/bristol-farms-yorba-l...
# 845   https://www.yelp.com/biz/apola-greek-grill-yor...
# 1101  https://www.yelp.com/biz/terra-wood-fired-kitc...
#
#                              Name              Street Address  Zip Code  \
# 4                           Dripp                                   NaN
# 257                         Dripp                                   NaN
# 255                 Awaken Coffee                                   NaN
# ...

# %%
# Sort by multiple columns:

data.sort_values( ['City', 'Price Range', 'Rating'], inplace=True )
data
# Out:
#                                               Yelp URL  \
# 4             https://www.yelp.com/biz/dripp-fullerton
# 257           https://www.yelp.com/biz/dripp-fullerton
# 255  https://www.yelp.com/biz/awaken-coffee-yorba-l...
# 42   https://www.yelp.com/biz/awaken-coffee-yorba-l...
# 761  https://www.yelp.com/biz/sugars-bikini-bar-ana...
# ..                                                 ...
# 504  https://www.yelp.com/biz/starbucks-pickup-yorb...
# 283  https://www.yelp.com/biz/perking-house-coffee-...
# 238  https://www.yelp.com/biz/bristol-farms-yorba-l...
# 705  https://www.yelp.com/biz/rileys-wing-factory-y...
# 636  https://www.yelp.com/biz/the-post-pub-yorba-linda
#
#                             Name                  Street Address  Zip Code  \
# 4                          Dripp                                       NaN
# 257                        Dripp                                       NaN
# 255                Awaken Coffee                                       NaN
# ...

# %%
# Show only

aanaheim_city = data.loc[data.City == 'Anaheim']
aanaheim_city
# Out:
#                                               Yelp URL  \
# 761  https://www.yelp.com/biz/sugars-bikini-bar-ana...
# 352  https://www.yelp.com/biz/king-coffee-usa-anahe...
# 9    https://www.yelp.com/biz/king-coffee-usa-anahe...
# 305    https://www.yelp.com/biz/market-house-anaheim-2
# 417  https://www.yelp.com/biz/compassion-cafe-anahe...
# ..                                                 ...
# 572  https://www.yelp.com/biz/manchester-bar-and-lo...
# 749             https://www.yelp.com/biz/h-bar-anaheim
# 533  https://www.yelp.com/biz/raymond-ave-brewing-c...
# 57   https://www.yelp.com/biz/hacea-coffee-source-a...
# 102        https://www.yelp.com/biz/and-more-anaheim-3
#
#                             Name  \
# 761            Sugars Bikini Bar
# 352              King Coffee USA
# 9                King Coffee USA
# 305                 Market House
# 417              Compassion Cafe
# ..                           ...
# 572      Manchester Bar & Lounge
# ...

# %%
aanaheim_city.tail(50)
# Out:
#                                                Yelp URL  \
# 134   https://www.yelp.com/biz/okayama-kobo-bakery-a...
# 16     https://www.yelp.com/biz/la-dolce-vita-anaheim-2
# 17     https://www.yelp.com/biz/allmytea-cafe-anaheim-5
# 1045    https://www.yelp.com/biz/puesto-anaheim-anaheim
# 26    https://www.yelp.com/biz/board-and-brew-anahei...
# 28         https://www.yelp.com/biz/lit-cafe-oc-anaheim
# 100   https://www.yelp.com/biz/thank-you-coffee-anah...
# 37    https://www.yelp.com/biz/le-parfait-paris-anah...
# 106     https://www.yelp.com/biz/the-cafe-krave-anaheim
# 1105  https://www.yelp.com/biz/reunion-kitchen-drink...
# 895   https://www.yelp.com/biz/craft-by-smoke-and-fi...
# 347      https://www.yelp.com/biz/sunbliss-cafe-anaheim
# 1203              https://www.yelp.com/biz/1901-anaheim
# 905      https://www.yelp.com/biz/luck-gai-cafe-anaheim
# 598   https://www.yelp.com/biz/craft-by-smoke-and-fi...
# 484   https://www.yelp.com/biz/craft-by-smoke-and-fi...
# ...

# %%
aanaheim_city.sort_values(['City', 'Price Range', 'Rating'], ascending=[True, True, False], inplace=True)
aanaheim_city
# Out:
# C:\Users\royaw\AppData\Local\Temp\ipykernel_3308\1618700266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aanaheim_city.sort_values(['City', 'Price Range', 'Rating'], ascending=[True, True, False], inplace=True)
#                                               Yelp URL  \
# 395   https://www.yelp.com/biz/chiptune-coffee-anaheim
# 167   https://www.yelp.com/biz/chiptune-coffee-anaheim
# 236   https://www.yelp.com/biz/lilypopp-cafe-anaheim-2
# 792     https://www.yelp.com/biz/the-beer-co-anaheim-5
# 48    https://www.yelp.com/biz/lilypopp-cafe-anaheim-2
# ..                                                 ...
# 804  https://www.yelp.com/biz/ruby-s-sports-bar-ana...
# 500  https://www.yelp.com/biz/common-grounds-market...
# 47   https://www.yelp.com/biz/the-wee-bakery-and-ca...
# ...

# %%
# 6 Count Values:

aanaheim_city.shape
# Out:
# (150, 18)

# %%
data.shape
# Out:
# (1263, 18)

# %%
data.count() #Only non missing values counted
# Out:
# Yelp URL             1263
# Name                 1263
# Street Address       1263
# Zip Code             1259
# City                 1263
# State                1259
# Price Range          1059
# Phone                1187
# Rating               1260
# Number of Reviews    1260
# Website               965
# Menu Link             582
# Image 1              1258
# Image 2              1252
# Image 3              1245
# Category 1           1263
# Category 2            994
# Category 3            660
# dtype: int64

# %%
data.Website.count()
# Out:
# 965

# %%
data[['Website', 'Rating']].count()
# Out:
# Website     965
# Rating     1260
# dtype: int64

# %% [markdown]
# #### Lecture 144 Count unique values:

# %%
# 6 Count unique values

data.City.nunique()
# Out:
# 44

# %%
data['Name'].nunique()
# Out:
# 786

# %%
# Find number of unique Restaurants by city:

data['City'].value_counts()
# Out:
# City
# Brea                      154
# Fullerton                 154
# Anaheim                   150
# Diamond Bar                74
# Rowland Heights            72
# Orange                     68
# Yorba Linda                63
# Buena Park                 44
# Chino Hills                44
# West Covina                39
# Whittier                   35
# Garden Grove               35
# La Habra                   33
# Pomona                     29
# Placentia                  28
# Walnut                     27
# Chino                      24
# City of Industry           24
# Claremont                  22
# Covina                     21
# La Mirada                  19
# Hacienda Heights           17
# Ontario                    12
# Stanton                     9
# Anaheim Hills               8
# La Palma                    6
# La Puente                   6
# Upland                      6
# Cypress                     6
# El Monte                    5
# Cerritos                    5
# ...

# %% [markdown]
# #### Lecture 145 Get All Unique Values

# %%
# 7 Unique Values
# Obtyain a numpy array of unique cities

cities = data.City.unique()
cities
# Out:
# array(['500 N Harbor Blvd', '5091 Mountain View Ave', 'Anaheim',
#        'Anaheim Hills', 'Baldwin Park', 'Brea', 'Buena Park', 'Cerritos',
#        'Chino', 'Chino Hills', 'City Of Industry', 'City of Industry',
#        'City of Industry ', 'Claremont', 'Corona', 'Covina', 'Cypress',
#        'Diamond Bar', 'El Monte', 'Fullerton', 'Garden Grove',
#        'Hacienda Heights', 'La Habra', 'La Mirada', 'La Palma',
#        'La Puente', 'La Verne', 'Montclair', 'Norwalk', 'Ontario',
#        'Orange', 'Placentia', 'Pomona', 'Rowland Heights', 'Santa Ana',
#        'Stanton', 'Tustin', 'Upland', 'Villa Park', 'Walnut',
#        'West Covina', 'Westminster', 'Whittier', 'Yorba Linda'],
#       dtype=object)

# %% [markdown]
# #### Lecture 146 Aggregation and Summary Statistics

# %%
# 8 Column Aggregations and Statistical Analysis

data.Rating.mean()
# Out:
# 4.257539682539683

# %%
data.Rating.mode()
# Out:
# 0    4.5
# Name: Rating, dtype: float64

# %%
data.Rating.std()
# Out:
# 0.48828888067369863

# %%
data.Rating.median()
# Out:
# 4.5

# %%
data.Rating.max()
# Out:
# 5.0

# %%
data.Rating.min()
# Out:
# 1.5

# %%
data[['Rating', 'Number of Reviews']].mean()
# Out:
# Rating                 4.257540
# Number of Reviews    571.660317
# dtype: float64

# %%
data[['Rating', 'Number of Reviews']].describe()
# Out:
#             Rating  Number of Reviews
# count  1260.000000        1260.000000
# mean      4.257540         571.660317
# std       0.488289         832.291903
# min       1.500000           1.000000
# 25%       4.000000          87.000000
# 50%       4.500000         261.000000
# 75%       4.500000         680.250000
# max       5.000000        6836.000000

# %%
# Or as he does it:

data[['Rating', 'Number of Reviews']].agg(['mean', 'median', 'std', 'min', 'max',])
# Out:
#           Rating  Number of Reviews
# mean    4.257540         571.660317
# median  4.500000         261.000000
# std     0.488289         832.291903
# min     1.500000           1.000000
# max     5.000000        6836.000000

# %% [markdown]
# #### Lecture 147 Vectorised Computations:

# %%
data.Rating + data['Number of Reviews']
# Out:
# 4      942.0
# 257    942.0
# 255      9.5
# 42       9.5
# 761     14.5
#        ...
# 504     17.0
# 283      6.0
# 238    253.0
# 705     14.5
# 636     17.0
# Length: 1263, dtype: float64

# %%
data.City + ' ' + data.State
# Out:
# 4                 NaN
# 257               NaN
# 255               NaN
# 42                NaN
# 761        Anaheim CA
#             ...
# 504    Yorba Linda CA
# 283    Yorba Linda CA
# 238    Yorba Linda CA
# 705    Yorba Linda CA
# 636    Yorba Linda CA
# Length: 1263, dtype: object

# %%
# Add a column

data['City_Stae'] = data.City + ' ' + data.State

# %%
data.head(2)
# Out:
#                                      Yelp URL   Name Street Address  Zip Code  \
# 4    https://www.yelp.com/biz/dripp-fullerton  Dripp                      NaN
# 257  https://www.yelp.com/biz/dripp-fullerton  Dripp                      NaN
#
#                   City State Price Range           Phone  Rating  \
# 4    500 N Harbor Blvd   NaN           $  (714) 441-1003     4.0
# 257  500 N Harbor Blvd   NaN           $  (714) 441-1003     4.0
#
#      Number of Reviews        Website Menu Link  \
# 4                938.0  www.dripp.com       NaN
# 257              938.0  www.dripp.com       NaN
#
#                                                Image 1  \
# 4    https://s3-media0.fl.yelpcdn.com/bphoto/zdCaor...
# 257  https://s3-media0.fl.yelpcdn.com/bphoto/zdCaor...
#
#                                                Image 2  \
# 4    https://s3-media0.fl.yelpcdn.com/bphoto/Tpbn2s...
# 257  https://s3-media0.fl.yelpcdn.com/bphoto/Tpbn2s...
#
# ...

# %%
# Add a Scalar to a vector

data.Rating = data.Rating + 10

# %%
data
# Out:
#                                               Yelp URL  \
# 4             https://www.yelp.com/biz/dripp-fullerton
# 257           https://www.yelp.com/biz/dripp-fullerton
# 255  https://www.yelp.com/biz/awaken-coffee-yorba-l...
# 42   https://www.yelp.com/biz/awaken-coffee-yorba-l...
# 761  https://www.yelp.com/biz/sugars-bikini-bar-ana...
# ..                                                 ...
# 504  https://www.yelp.com/biz/starbucks-pickup-yorb...
# 283  https://www.yelp.com/biz/perking-house-coffee-...
# 238  https://www.yelp.com/biz/bristol-farms-yorba-l...
# 705  https://www.yelp.com/biz/rileys-wing-factory-y...
# 636  https://www.yelp.com/biz/the-post-pub-yorba-linda
#
#                             Name                  Street Address  Zip Code  \
# 4                          Dripp                                       NaN
# 257                        Dripp                                       NaN
# 255                Awaken Coffee                                       NaN
# ...

# %% [markdown]
# #### Lecture 148.  Conditional Computations/Assignment by Rows:

# %%
data.loc[data.City == 'Anaheim', 'Rating'] = data.Rating + 1
data.loc[data.City == 'Anaheim'].head(5)
# Out:
#                                               Yelp URL               Name  \
# 761  https://www.yelp.com/biz/sugars-bikini-bar-ana...  Sugars Bikini Bar
# 352  https://www.yelp.com/biz/king-coffee-usa-anahe...    King Coffee USA
# 9    https://www.yelp.com/biz/king-coffee-usa-anahe...    King Coffee USA
# 305    https://www.yelp.com/biz/market-house-anaheim-2       Market House
# 417  https://www.yelp.com/biz/compassion-cafe-anahe...    Compassion Cafe
#
#                                     Street Address  Zip Code     City State  \
# 761                           405 S Brookhurst St    92804.0  Anaheim    CA
# 352                          321 W Katella Ste 142   92802.0  Anaheim    CA
# 9                            321 W Katella Ste 142   92802.0  Anaheim    CA
# 305                            1313 Disneyland Dr    92802.0  Anaheim    CA
# 417  3330 E Miraloma Ave Eastside Christian Church   92806.0  Anaheim    CA
#
#     Price Range           Phone  Rating  Number of Reviews  \
# ...

# %%
data.loc[data.City == 'Anaheim', 'Rating'].mean()
# Out:
# 17.302013422818792
